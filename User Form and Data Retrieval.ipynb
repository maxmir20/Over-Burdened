# %%
'''
Form considerations
-income (ordinal)
-Rent control (binary)
-Zipcode
-Roommates
-Dependents
'''

'''
Output Considerations
- Risk level now
- Spending Percentage
- Risk level in X years
'''
import numpy as np
import IPython
import pandas as pd
import matplotlib as plt
import itertools

#read ML model (returns predicted next year price and 2021 price)
datathon = pd.read_csv("Predicted_Outcome.csv", low_memory=False, encoding = "ISO-8859-1")


#User input
def user_input():
    print('Sustainable Housing Rental Calculator')
    print()
    income = int(input('What is your annual household income: '))
    # bedrooms = int(input('How many bedrooms does your place have: '))
    # people = int(input('How many roommates do you live with (not including yourself): ')) + 1 #+1 is for the user entering
    # rent_control = bool(input('Is your place rent controlled: y/n '))
    zipcode = int(input('Please enter your 5 digit zipcode: '))

    
    #Pass zipcode to ML model to return results
    ML_return = datathon[datathon['RegionName'] == zipcode]
    ML_next_year = round(ML_return['2020'].tolist()[0])
    ML_2021 = round(ML_return['2021'].tolist()[0])
    
    
    #plug into rental calculator
    rental_calculator(income, bedrooms, people, zipcode, ML_return)

    
    


#risk model

def rental_calculator(income, bedrooms, people, zipcode, ML_return):


    #ML Return: Average
    ML_next_year = round(ML_return['2020'].tolist()[0])
    ML_2021 = round(ML_return['2021'].tolist()[0])
    average = ML_return
    
    
    rent_burden = burden(income, people, ML_next_year)
    risk_score = risk_level(rent_burden)
    print ()

    print ('###########################################################################################################')
    print ()

    print ('PREDICTED RENT BURDEN:')
    print ('next year, the estimated average price for a 2 bedroom house in this zipcode is $' + str(ML_next_year)) #average ML return
    print( 'with a household income of $' + str(income)+ ' the average rent burden in this area would be ' + str(rent_burden) + '% of your monthly income')
    #Category of Over-burdening
    print ()
    print ('This is a risk level of ' + risk_score)

    print ()
    print ('2021 RENT BURDEN:')
    #forecasting
    projected = ML_2021 #2021 estimate of average price
    print('In 2021, the average cost of renting in this zipcode is predicted to be $' + str(projected))
    print ()
    print()
    print ('YEARS UNTIL >50% RENT BURDEN:')
    #years until risk_level becomes high
    years = years_until_burdened(income, people, projected)
    

    print('At your current rate (with no change in income) it will be ' + str(years) + ' years until you are spending more than 50 percent of your monthly income on rent')
    print ()
    print ('###########################################################################################################')

def burden(income, people, rental_cost):
    monthly_income = income/12 #converts to monthly amount
    return round(((rental_cost/people)/monthly_income) * 100)
        
def risk_level(rent_burden):
    risk_level = ''
    if rent_burden > 50:
        risk_level = 'High'
        #message = 'By spending over 50% of your income on rent, you increase the strain of supporting'
    elif rent_burden >30:
        risk_level = 'Medium'
        #message = 'By spending over '
    else:
        risk_level = 'Low'
    return risk_level
    
def years_until_burdened(income, people, projected):
    estimated = projected
    years = 0
    rent_control = 7.7 #pulled from current projected SF Rent control rates
    while burden(income, people, estimated) < 50:
        estimated = estimated + estimated*rent_control
        years += 1
    return years


def main():
    if __name__== "__main__" :
        user_input()
main()
# Out:
# Sustainable Housing Rental Calculator
#
# What is your annual household income: 93000
# Please enter your 5 digit zipcode: 94110
#
# ###########################################################################################################
#
# PREDICTED RENT BURDEN:
# next year, the estimated average price for a 2 bedroom house in this zipcode is $4439
# with a household income of $93000 the average rent burden in this area would be 57% of your monthly income
#
# This is a risk level of High
#
# 2021 RENT BURDEN:
# In 2021, the average cost of renting in this zipcode is predicted to be $5108
#
#
# YEARS UNTIL >50% RENT BURDEN:
# At your current rate (with no change in income) it will be 0 years until you are spending over 50 percent of your income on rent
#
# ###########################################################################################################

# %%
datathon = pd.read_csv("predicted_rent_burden.csv", low_memory=False, encoding = "ISO-8859-1")
datathon
# Out:
#     Unnamed: 0  Unnamed: 0.1  RegionName           City State  \
# 0           34            12       94109  San Francisco    CA
# 1           35            76       94501        Alameda    CA
# 2           36            85       94110  San Francisco    CA
# 3           37           182       94536        Fremont    CA
# 4           38           213       95123       San Jose    CA
# 5           39           255       95051    Santa Clara    CA
# 6           40           269       94568         Dublin    CA
# 7           41           279       94509        Antioch    CA
# 8           42           324       94538        Fremont    CA
# 9           43           365       94587     Union City    CA
# 10          44           382       95014      Cupertino    CA
# 11          45           389       95112       San Jose    CA
# 12          46           426       94087      Sunnyvale    CA
# 13          47           428       95125       San Jose    CA
# 14          48           458       94806      San Pablo    CA
# 15          49           509       95008       Campbell    CA
# 16          50           576       94115  San Francisco    CA
# 17          51           681       94117  San Francisco    CA
# 18          52           704       94102  San Francisco    CA
# 19          53           717       94121  San Francisco    CA
# 20          54           801       94546  Castro Valley    CA
# 21          55           805       94118  San Francisco    CA
# 22          56           820       94403      San Mateo    CA
# 23          57           883       94114  San Francisco    CA
# 24          58           888       94103  San Francisco    CA
# 25          59           906       94107  San Francisco    CA
# 26          60           936       94566     Pleasanton    CA
# 27          61           983       94025     Menlo Park    CA
# 28          62          1141       94608        Oakland    CA
# 29          63          1158       95126       San Jose    CA
# 30          64          1170       94404    Foster City    CA
# 31          65          1190       95050    Santa Clara    CA
# 32          66          1208       94560         Newark    CA
# 33          67          1255       94523  Pleasant Hill    CA
# 34          68          1257       94123  San Francisco    CA
# 35          69          1313       95129       San Jose    CA
# 36          70          1348       94583      San Ramon    CA
# 37          71          1436       95134       San Jose    CA
# 38          72          1474       94043  Mountain View    CA
# 39          73          1539       94133  San Francisco    CA
# 40          74          1758       94306      Palo Alto    CA
# 41          75          1847       94596   Walnut Creek    CA
# 42          76          1873       94597   Walnut Creek    CA
# 43          77          1876       95032      Los Gatos    CA
# 44          78          2178       94085      Sunnyvale    CA
# 45          79          2270       94105  San Francisco    CA
# 46          80          2361       95110       San Jose    CA
# 47          81          2438       94158  San Francisco    CA
#
#                              Metro            CountyName  RoomType  SizeRank  \
# 0    San Francisco-Oakland-Hayward  San Francisco County         2        13
# 1    San Francisco-Oakland-Hayward        Alameda County         2        77
# 2    San Francisco-Oakland-Hayward  San Francisco County         2        86
# 3    San Francisco-Oakland-Hayward        Alameda County         2       183
# 4   San Jose-Sunnyvale-Santa Clara    Santa Clara County         2       214
# 5   San Jose-Sunnyvale-Santa Clara    Santa Clara County         2       256
# 6    San Francisco-Oakland-Hayward        Alameda County         2       270
# 7    San Francisco-Oakland-Hayward   Contra Costa County         2       280
# 8    San Francisco-Oakland-Hayward        Alameda County         2       325
# 9    San Francisco-Oakland-Hayward        Alameda County         2       366
# 10  San Jose-Sunnyvale-Santa Clara    Santa Clara County         2       383
# 11  San Jose-Sunnyvale-Santa Clara    Santa Clara County         2       390
# 12  San Jose-Sunnyvale-Santa Clara    Santa Clara County         2       427
# 13  San Jose-Sunnyvale-Santa Clara    Santa Clara County         2       429
# 14   San Francisco-Oakland-Hayward   Contra Costa County         2       459
# 15  San Jose-Sunnyvale-Santa Clara    Santa Clara County         2       510
# 16   San Francisco-Oakland-Hayward  San Francisco County         2       577
# 17   San Francisco-Oakland-Hayward  San Francisco County         2       682
# 18   San Francisco-Oakland-Hayward  San Francisco County         2       705
# 19   San Francisco-Oakland-Hayward  San Francisco County         2       718
# 20   San Francisco-Oakland-Hayward        Alameda County         2       802
# 21   San Francisco-Oakland-Hayward  San Francisco County         2       805
# 22   San Francisco-Oakland-Hayward      San Mateo County         2       821
# 23   San Francisco-Oakland-Hayward  San Francisco County         2       884
# 24   San Francisco-Oakland-Hayward  San Francisco County         2       889
# 25   San Francisco-Oakland-Hayward  San Francisco County         2       907
# 26   San Francisco-Oakland-Hayward        Alameda County         2       937
# 27   San Francisco-Oakland-Hayward      San Mateo County         2       984
# 28   San Francisco-Oakland-Hayward        Alameda County         2      1142
# 29  San Jose-Sunnyvale-Santa Clara    Santa Clara County         2      1159
# 30   San Francisco-Oakland-Hayward      San Mateo County         2      1171
# 31  San Jose-Sunnyvale-Santa Clara    Santa Clara County         2      1191
# 32   San Francisco-Oakland-Hayward        Alameda County         2      1209
# 33   San Francisco-Oakland-Hayward   Contra Costa County         2      1256
# 34   San Francisco-Oakland-Hayward  San Francisco County         2      1258
# 35  San Jose-Sunnyvale-Santa Clara    Santa Clara County         2      1311
# 36   San Francisco-Oakland-Hayward   Contra Costa County         2      1349
# 37  San Jose-Sunnyvale-Santa Clara    Santa Clara County         2      1437
# 38  San Jose-Sunnyvale-Santa Clara    Santa Clara County         2      1475
# 39   San Francisco-Oakland-Hayward  San Francisco County         2      1540
# 40  San Jose-Sunnyvale-Santa Clara    Santa Clara County         2      1759
# 41   San Francisco-Oakland-Hayward   Contra Costa County         2      1848
# 42   San Francisco-Oakland-Hayward   Contra Costa County         2      1873
# 43  San Jose-Sunnyvale-Santa Clara    Santa Clara County         2      1877
# 44  San Jose-Sunnyvale-Santa Clara    Santa Clara County         2      2179
# 45   San Francisco-Oakland-Hayward  San Francisco County         2      2271
# 46  San Jose-Sunnyvale-Santa Clara    Santa Clara County         2      2362
# 47   San Francisco-Oakland-Hayward  San Francisco County         2      2439
#
#     2017-01  ...  2019-05  2019-06  2019-07  2019-08  2019-09         2020  \
# 0    4495.0  ...   4650.0   4700.0   4750.0   4750.0   4700.0  4741.640625
# 1    2397.5  ...   2475.0   2494.0   2500.0   2508.0   2550.0  2548.043655
# 2    3995.0  ...   4095.0   4300.0   4385.0   4500.0   4297.5  4438.817657
# 3    2600.0  ...   2769.5   2786.0   2700.0   2700.0   2700.0  2681.684933
# 4    2695.0  ...   2910.0   2996.0   2950.0   2899.0   2850.0  2868.864653
# 5    2807.5  ...   3378.5   3112.0   3079.0   3162.0   3095.0  3137.544128
# 6    2700.0  ...   2856.0   2894.5   2900.0   2882.5   2805.0  2668.357440
# 7    1500.0  ...   1800.0   1850.0   1800.0   1850.0   1850.0  1921.093750
# 8    2415.0  ...   2867.0   2797.5   2774.5   2756.5   2700.0  2627.348982
# 9    2397.5  ...   2508.0   2508.0   2556.0   2607.5   2526.5  2626.825862
# 10   3195.0  ...   3500.0   3495.0   3458.0   3550.0   3500.0  3555.945578
# 11   2972.0  ...   3020.0   3025.0   3110.0   3185.0   2885.0  2901.563242
# 12   2712.0  ...   3200.0   3338.5   3200.0   3176.0   3100.0  2978.358632
# 13   2552.0  ...   2850.0   2850.0   2860.0   2695.0   2895.0  2923.481845
# 14   2170.0  ...   2300.0   2237.0   2205.0   2174.5   2240.0  2129.852659
# 15   2495.0  ...   2850.0   2980.0   3069.5   2942.0   2919.0  3110.763287
# 16   4195.0  ...   4150.0   4244.0   4495.0   4528.0   4493.0  4377.920285
# 17   3887.5  ...   3900.0   3995.0   4150.0   4200.0   4197.0  4130.062804
# 18   4550.0  ...   5387.5   5240.0   5098.5   4960.0   5110.0  5198.381128
# 19   3700.0  ...   3537.5   3495.0   3465.0   3500.0   3450.0  3539.435122
# 20   2189.0  ...   2305.0   2425.0   2350.0   2372.5   2350.0  2445.043096
# 21   3450.0  ...   3600.0   3695.0   3750.0   3750.0   3800.0  3706.091023
# 22   2891.5  ...   3969.0   3950.0   3988.0   3872.0   3720.5  3762.783369
# 23   4725.0  ...   4950.0   4800.0   4975.0   5035.5   5150.0  5752.538653
# 24   4745.0  ...   4900.0   4884.5   4968.5   4911.5   4895.0  4733.990445
# 25   4660.0  ...   4935.0   4979.0   4999.0   5034.0   5080.0  5165.312500
# 26   2473.0  ...   2792.5   2870.0   2900.0   2627.5   2665.0  2623.722533
# 27   3295.0  ...   3725.0   4365.0   4405.0   4432.0   4250.0  4443.984375
# 28   3235.0  ...   3222.5   3345.0   3386.5   3403.0   3390.0  3325.090912
# 29   2905.0  ...   3530.0   3498.5   3505.0   3605.0   3507.5  3700.564175
# 30   3355.0  ...   3930.5   3920.0   3959.0   3835.0   3800.0  3723.157734
# 31   2400.0  ...   2905.0   3028.0   3100.0   3100.0   2900.0  3056.579491
# 32   2643.0  ...   2700.0   2862.5   2825.0   2792.5   2775.0  2831.952932
# 33   2397.5  ...   2625.5   2585.0   2600.0   2529.0   2500.0  2520.820312
# 34   5000.0  ...   5097.5   5000.0   5200.0   5322.5   5250.0  5300.781250
# 35   2531.0  ...   2938.0   2986.5   2931.5   3032.5   3017.0  3123.425125
# 36   2400.0  ...   2511.5   2520.0   2575.0   2520.0   2442.5  2401.763358
# 37   3005.0  ...   3395.5   3470.0   3460.0   3375.0   3340.5  3188.340930
# 38   3397.5  ...   3622.5   3980.0   3657.5   3650.0   3580.0  3613.627384
# 39   3995.0  ...   4454.0   4395.0   4500.0   4502.0   4679.0  4543.924968
# 40   3525.0  ...   3900.0   4137.5   4000.0   4197.5   4225.0  4622.832335
# 41   2435.5  ...   2812.5   2951.5   2906.0   2835.0   2750.0  2571.161202
# 42   2650.0  ...   2750.0   2750.0   2750.0   2760.0   2695.0  2831.977936
# 43   2850.0  ...   3425.0   3399.5   3364.5   3325.5   3350.0  3447.351465
# 44   3109.5  ...   3440.0   3790.0   3815.0   3692.5   3520.0  3472.127940
# 45   5698.5  ...   6235.0   6135.0   6023.0   5939.0   5995.0  6019.834757
# 46   3268.5  ...   3221.0   3200.0   3209.5   3351.0   3205.0  3185.221303
# 47   4814.0  ...   5450.0   5500.0   5500.0   5303.0   5406.0  5532.599234
#
#             2021         2022  rentburden2020  rentburden2021
# 0    5299.869792  4414.036458        0.592705        0.662484
# 1    2685.445405  2316.759995        0.318505        0.335681
# 2    5107.558582  4199.960785        0.554852        0.638445
# 3    2900.129031  2454.031701        0.335211        0.362516
# 4    3036.556560  2616.707972        0.358608        0.379570
# 5    3480.630509  2925.147881        0.392193        0.435079
# 6    1887.428384  2114.627662        0.333545        0.235929
# 7    2359.635417  1876.302083        0.240137        0.294954
# 8    2819.287910  2386.898106        0.328419        0.352411
# 9    3389.480332  2605.992906        0.328353        0.423685
# 10   4021.889336  3338.741228        0.444493        0.502736
# 11   3133.203764  2669.035932        0.362695        0.391650
# 12   2163.954833  2395.441331        0.372295        0.270494
# 13   3274.637199  2725.106998        0.365435        0.409330
# 14   1578.492855  1703.986573        0.266232        0.197312
# 15   3789.500363  3026.129623        0.388845        0.473688
# 16   4748.375390  4017.526074        0.547240        0.593547
# 17   4465.734820  3783.326813        0.516258        0.558217
# 18   5984.200283  4910.033785        0.649798        0.748025
# 19   3838.684351  3248.117519        0.442429        0.479836
# 20   3118.655940  2411.190545        0.305630        0.389832
# 21   4004.808706  3388.687999        0.463261        0.500601
# 22   3589.520500  3348.561196        0.470348        0.448690
# 23  10048.485560  6589.440141        0.719067        1.256061
# 24   5100.563885  4315.951540        0.591749        0.637570
# 25   5929.895833  4873.229167        0.645664        0.741237
# 26   2258.781870  2219.848487        0.327965        0.282348
# 27   5574.088542  4388.255208        0.555498        0.696761
# 28   3602.181821  3048.000002        0.415636        0.450273
# 29   4564.735112  3623.542835        0.462571        0.570592
# 30   3931.766742  3349.263440        0.465395        0.491471
# 31   3708.292765  2970.967848        0.382072        0.463537
# 32   3359.573131  2704.398168        0.353994        0.419947
# 33   2812.434896  2344.518229        0.315103        0.351554
# 34   5941.406250  4941.406250        0.662598        0.742676
# 35   3755.021870  3016.890538        0.390428        0.469378
# 36   2266.052779  2094.210419        0.300220        0.283257
# 37   3443.890541  2915.269786        0.398543        0.430486
# 38   4091.580166  3385.121532        0.451703        0.511448
# 39   5171.628941  4268.387337        0.567991        0.646454
# 40   7253.871346  5044.030874        0.577854        0.906734
# 41   1381.911472  1902.006686        0.321395        0.172739
# 42   3677.694897  2807.142043        0.353997        0.459712
# 43   4075.230034  3301.105921        0.430919        0.509404
# 44   3118.949035  2998.452910        0.434016        0.389869
# 45   6550.171073  5542.376936        0.752479        0.818771
# 46   3274.087773  2864.472111        0.398153        0.409261
# 47   6553.882797  5291.964429        0.691575        0.819235
#
# [48 rows x 47 columns]

# %%
zipcode = 94110
ML_return = datathon[datathon['RegionName'] == zipcode]

# %%
data1 = round(data['2020'].tolist()[0])
data2 = round(data['2021'].tolist()[0])
data1
# Out:
# 4439
